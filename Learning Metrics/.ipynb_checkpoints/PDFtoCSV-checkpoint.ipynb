# %%
import pdfplumber
import pandas as pd
import os
import re
state_names = [
    "ALABAMA", "ALASKA", "ARIZONA", "ARKANSAS", "CALIFORNIA", "COLORADO", "CONNECTICUT", "DELAWARE", "FLORIDA", 
    "GEORGIA", "HAWAII", "IDAHO", "ILLINOIS", "INDIANA", "IOWA", "KANSAS", "KENTUCKY", "LOUISIANA", "MAINE", 
    "MARYLAND", "MASSACHUSETTS", "MICHIGAN", "MINNESOTA", "MISSISSIPPI", "MISSOURI", "MONTANA", "NEBRASKA", 
    "NEVADA", "NEW HAMPSHIRE", "NEW JERSEY", "NEW MEXICO", "NEW YORK", "NORTH CAROLINA", "NORTH DAKOTA", "OHIO", 
    "OKLAHOMA", "OREGON", "PENNSYLVANIA", "RHODE ISLAND", "SOUTH CAROLINA", "SOUTH DAKOTA", "TENNESSEE", "TEXAS", 
    "UTAH", "VERMONT", "VIRGINIA", "WASHINGTON", "WEST VIRGINIA", "WISCONSIN", "WYOMING"
]

#sm_states are for 2020 and 2021 which are vastly different to the other data sets

sm_state_names = ['Alaska', 'Alabama','Arkansas','Arizona', 'California', 'Colorado', 'Connecticut', 'District of Columbia', 
                     'Delaware','Florida','Georgia','Hawaii','Iowa','Idaho','Illinois','Indiana','Kansas','Kentucky','Louisiana', 'Massachusetts',
                     'Maryland', 'Maine', 'Michigan', 'Minnesota', 'Missouri', 'Mississippi', 'Montana', 'North Carolina', 'North Dakota',
                     'Nebraska', 'New Hampshire', 'New Jersey', 'New Mexico', 'Nevada', 'New York', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania',
                     'Rhode Island', 'South Carolina','South Dakota', 'Tennessee', 'Texas', 'Utah', 'Virginia', 'Vermont', 'Washington', 'Wisconsin',
                     'West Virginia', 'Wyoming']
                     
def extract_table_from_pdf_plumber(pdf_path):
    # Open the PDF using pdfplumber
    with pdfplumber.open(pdf_path) as pdf:
        
        # Find the start and end pages of the table
        start_page = None
        end_page = None
        for i, page in enumerate(pdf.pages):
            text = page.extract_text()
            if "ALABAMA" in text or ("HOUSE" in text and "Alabama" in text) or ("Alabama" in text):
                start_page = i
            if "WYOMING" in text or "Wyoming" in text:
                end_page = i
                break
        
        # If start or end page is not found, return an empty DataFrame
        if start_page is None or end_page is None:
            return pd.DataFrame()
        
        # Extract text from the identified range of pages
        text = ""
        for page_num in range(start_page, end_page + 1):
            text += pdf.pages[page_num].extract_text()

    # Split the text into lines
    lines = text.split('\n')
   
    # Initialize lists to store data
    seats = []
    states = []
    names = []
    lq_scores = []

    # Variables to keep track of current state
    current_state = None

    # Iterate through the lines to extract data
    for line in lines:

        index = lines.index(line)        
        
        
      # This is for 2010-2019 to set the current state                  

        if any(state in line for state in state_names):
            current_state = line.replace("(cont.)", "").strip()
            
        

        #Fixing bugs for 2021.
        
        if line.count('%') > 1:
            index = lines.index(line)
            temp_line = line.split('%')
            temp_line[0] = temp_line[0] + '%'
            temp_line[1] = temp_line[1] + '%'
            lines[index] = temp_line[0]
            lines.insert(index + 1, temp_line[1])
            
        elif any(state in line for state in sm_state_names):
            if '%' in line:
                if '1' in line:
                    temp_line = line.split('1 ')
                    temp_line[1] = "1 " + temp_line[1]
                    lines[index] = temp_line[0]
                    lines.insert(index + 1, temp_line[1])
                    current_state = temp_line[0].upper()
                    
                else:
                    temp_line = line.split('%')
                    temp_line[0] = temp_line[0] + '%'
                    lines.insert(index + 1, temp_line[0])
                    lines.insert(index + 2, temp_line[1])

            elif 'Congressional' in line: 
                continue
                
            else:
                current_state = line.upper()

        #Here we deal with 2010-2019
        
        elif any(char.isdigit() for char in line) and "%" in line:

            parts = line.split()
            if parts[0] == 'ADA':
                continue
            seats.append(parts[0])
            names.append(' '.join(parts[1:-1]))
            lq_scores.append(parts[-1])
            #upper_current_state = current_state.upper()
            states.append(current_state)

        # Here I deal with pdf 2020 - a mess of a pdf. Lots of misread lines etc.
        
        if current_state == 'Delaware' and 'AL D' in line:
            line = 'AL Blunt Rochester D + + + + + + + + + + + + - + + + + - + + 90'

        elif current_state == 'South Carolina' and '3 R' in line:
            line = '3 Duncan Jeff R - - - - - - - - - - - - + - X - - - - - 5'
            
        elif current_state == 'Ohio' and '14 R' in line:
            line = '14 Joyce David R - + - - + - - - - - - + - - - - - - - - 15'
            
        elif current_state == 'Florida' and '23 D' in line:
            line ='23 Wasserman Schultz D + + + + + + + + + + + + - + + + - - + + 85'
            
        elif current_state == 'California' and '5 D' in line:
            line = '5 Thompson D + + + + + + + + + + + + - + + + + - + + 90'
            
        elif current_state == 'California' and '40 D' in line:
            line = '40 Roybal-Allard D + + + + + + + + + + + + - X + + - - + + 80'

        elif current_state == 'California' and '43 D' in line:
            line = '43 Waters Maxine D + + + + + + + + + + + X + + + + + + + + 95'
            
        elif current_state == 'Florida' and '26 D' in line:
            line = '26 Mucarsel Powell D + + + + + + + + + + + + - + + + - - + + 85'
            
        elif current_state == 'Massachusetts' and '4 D' in line:
            line = '4 Kennedy Joseph P. D + + + + + + + + + + + + + + + + + + + + 100'

        elif current_state == 'Pennsylvania' and '15 R' in line:
            line = '15 Thompson G. R - - - - + - - - - - - - - - - - - - - - 5'

        elif current_state == 'Nebraska' and '3 R' in line:
            line = '3 Smith Adrian R - - - - + - - - - - - - - - - - - - - - 5'

        elif current_state == 'New Jersey' and '12 D' in line:
            line = '12 Watson Coleman D + + + + + + + + + + + + + + + + + + + + 100'

        elif current_state == 'New Mexico' and '2 D' in line:
            line = '2 Torres Small D + + + + + + + + + + + + - - + + - - + + 80'

        elif current_state == 'New York' and '14 D' in line:
            line = "14 Ocasio Cortez D + + + + + + + + + + + + + + + + + + + + 100"

        elif current_state == 'New York' and '18 D' in line:
            line = '18 Maloney S.P. D + + + + + + + + + + + + - + + + - - + + 85'

        elif current_state == 'Washington' and '3 R' in line:
            line = '3 Herrera Beutler R - + - - + - - - - - - X + - - - - - + - 20'
            
        elif current_state == 'Texas' and '30 D' in line:
            line = '30 Johnson E.B. D + + + + + + + + + + + + - + + + + + + + 95'

        elif current_state == 'Mississippi' and '2 D' in line:
            line = '2 Thompson B. D + + + + + + + + + + - + - + + + + + + + 90'


        if any(char.isdigit() for char in line) and (" R " in line or " D " in line) and "%" not in line:
            if current_state == None:
                continue
            parts = line.split()
            if parts[0] == 'ADA':
                continue
            seats.append(parts[0])
            names.append(' '.join(parts[1:-1]))
            lq_scores.append(parts[-1])
            #upper_current_state = current_state.upper()
            states.append(current_state)


    # Create a pandas DataFrame
    df = pd.DataFrame({
        'Seat': seats,
        'State': states,
        'Name': names,
        'LQ Score': lq_scores
    })
    # Extract the year from the file name
    year = os.path.basename(pdf_path).split('.')[0]
    df['Year'] = year

    # Remove the '%' symbol, fill NaN values with 0, and then convert to integer
    df['LQ Score'] =  df['LQ Score'].str.extract('(\d+)').fillna(0).astype(int)

    # Clean up the 'Name' column by removing any unwanted characters
    df['Name'] = df['Name'].str.replace('[^a-zA-Z\s.]|X', '', regex=True).str.strip()
    df['Name'] = df['Name'].str.replace('A Newsletter for Liberal', '', regex=False).str.strip()

    return df

# Example usage remains the same as in your code.

# %%
# Example usage:
base_path = "/Users/jorgebruno/Downloads/Learning Metrics/downloaded_pdfs"
pdf_paths = [os.path.join(base_path, f"{year}.pdf") for year in range(2011, 2012)]  # List of paths to your PDF files
dfs = []  # List to store DataFrames for each PDF

for pdf_path in pdf_paths:
    dfs.append(extract_table_from_pdf_plumber(pdf_path))

# Combine all DataFrames into one
final_df = pd.concat(dfs, ignore_index=True)
pd.set_option('display.max_rows', 1000)

final_df
# Out:
#     Seat           State                               Name  LQ Score  Year
# 0      4         ALABAMA                         Aderholt R        10  2011
# 1      6         ALABAMA                        Bachus S. R         0  2011
# 2      1         ALABAMA                           Bonner R         5  2011
# 3      5         ALABAMA                           Brooks R         5  2011
# 4      2         ALABAMA                             Roby R         0  2011
# 5      3         ALABAMA                   Rogers Mike D. R         5  2011
# 6      7         ALABAMA                           Sewell D        75  2011
# 7     AL          ALASKA                         Young D. R        30  2011
# 8      6         ARIZONA                            Flake R         0  2011
# 9      2         ARIZONA                        Franks T. R         0  2011
# 10     1         ARIZONA                            Gosar R         0  2011
# 11     7         ARIZONA                         Grijalva D       100  2011
# 12     4         ARIZONA                           Pastor D       100  2011
# 13     3         ARIZONA                           Quayle R         0  2011
# 14     5         ARIZONA                       Schweikert R         5  2011
# 15     1        ARKANSAS                         Crawford R         0  2011
# 16     2        ARKANSAS                         Griffi n R         0  2011
# 17     4        ARKANSAS                          Ross M. D        35  2011
# 18     3        ARKANSAS                           Womack R         0  2011
# 19    43      CALIFORNIA                             Baca D        75  2011
# 20    33      CALIFORNIA                          Bass K. D        90  2011
# 21    31      CALIFORNIA                          Becerra D        90  2011
# 22    28      CALIFORNIA                           Berman D        85  2011
# 23    50      CALIFORNIA                          Bilbray R         0  2011
# 24    45      CALIFORNIA                        Bono Mack R        10  2011
# 25    44      CALIFORNIA                          Calvert R         0  2011
# 26    48      CALIFORNIA                         Campbell R        15  2011
# 27    23      CALIFORNIA                            Capps D        90  2011
# 28    18      CALIFORNIA                          Cardoza D        60  2011
# 29    32      CALIFORNIA                              Chu D       100  2011
# 30    20      CALIFORNIA                            Costa D        55  2011
# 31    53      CALIFORNIA                         Davis S. D        80  2011
# 32    19      CALIFORNIA                           Denham R         0  2011
# 33    26      CALIFORNIA                           Dreier R         5  2011
# 34    14      CALIFORNIA                            Eshoo D        90  2011
# 35    17      CALIFORNIA                             Farr D       100  2011
# 36    51      CALIFORNIA                           Filner D        90  2011
# 37    24      CALIFORNIA                         Gallegly R         0  2011
# 38    10      CALIFORNIA                        Garamendi D        90  2011
# 39     2      CALIFORNIA                           Herger R         0  2011
# 40    15      CALIFORNIA                            Honda D        95  2011
# 41    52      CALIFORNIA                           Hunter R        10  2011
# 42    49      CALIFORNIA                             Issa R         0  2011
# 43     9      CALIFORNIA                              Lee D       100  2011
# 44    41      CALIFORNIA                      Lewis Jerry R         0  2011
# 45    16      CALIFORNIA                          Lofgren D        85  2011
# 46     3      CALIFORNIA                          Lungren R         0  2011
# 47     5      CALIFORNIA                           Matsui D        90  2011
# 48    22      CALIFORNIA                      McCarthy K. R         0  2011
# 49     4      CALIFORNIA                       McClintock R        10  2011
# 50    25      CALIFORNIA                           McKeon R         0  2011
# 51    11      CALIFORNIA                         McNerney D        90  2011
# 52     7      CALIFORNIA                    Miller George D       100  2011
# 53    42      CALIFORNIA                      Miller Gary R         0  2011
# 54    38      CALIFORNIA                       Napolitano D        95  2011
# 55    21      CALIFORNIA                            Nunes R         0  2011
# 56     8      CALIFORNIA                           Pelosi D        75  2011
# 57    37      CALIFORNIA                       Richardson D        95  2011
# 58    46      CALIFORNIA                      Rohrabacher R        20  2011
# 59    34      CALIFORNIA                     RoybalAllard D        95  2011
# 60    40      CALIFORNIA                            Royce R         0  2011
# 61    39      CALIFORNIA                    Sanchez Linda D       100  2011
# 62    47      CALIFORNIA                  Sanchez Loretta D        85  2011
# 63    29      CALIFORNIA                           Schiff D        80  2011
# 64    27      CALIFORNIA                          Sherman D        90  2011
# 65    12      CALIFORNIA                           Speier D        90  2011
# 66    13      CALIFORNIA                            Stark D        95  2011
# 67     1      CALIFORNIA                      Thompson M. D        90  2011
# 68    35      CALIFORNIA                           Waters D        95  2011
# 69    30      CALIFORNIA                           Waxman D        95  2011
# 70     6      CALIFORNIA                          Woolsey D        95  2011
# 71     6        COLORADO                          Coffman R         5  2011
# 72     1        COLORADO                          DeGette D        90  2011
# 73     4        COLORADO                          Gardner R         0  2011
# 74     5        COLORADO                          Lamborn R         0  2011
# 75     7        COLORADO                       Perlmutter D        75  2011
# 76     2        COLORADO                            Polis D        85  2011
# 77     3        COLORADO                           Tipton R         0  2011
# 78     2     CONNECTICUT                         Courtney D        80  2011
# 79     3     CONNECTICUT                          DeLauro D        90  2011
# 80     4     CONNECTICUT                            Himes D        85  2011
# 81     1     CONNECTICUT                        Larson J. D        90  2011
# 82     5     CONNECTICUT                        Murphy C. D        85  2011
# 83    AL        DELAWARE                           Carney D        80  2011
# 84    24         FLORIDA                            Adams R         5  2011
# 85     9         FLORIDA                        Bilirakis R         0  2011
# 86     3         FLORIDA                         Brown C. D        90  2011
# 87    13         FLORIDA                         Buchanan R         0  2011
# 88    11         FLORIDA                           Castor D        75  2011
# 89     4         FLORIDA                         Crenshaw R         5  2011
# 90    19         FLORIDA                           Deutch D        80  2011
# 91    21         FLORIDA                       DiazBalart R        20  2011
# 92    23         FLORIDA                      Hastings A. D        95  2011
# 93    14         FLORIDA                             Mack R        10  2011
# 94     7         FLORIDA                             Mica R         0  2011
# 95     1         FLORIDA                        Miller J. R         0  2011
# 96     5         FLORIDA                           Nugent R         0  2011
# 97    15         FLORIDA                            Posey R         0  2011
# 98    25         FLORIDA                           Rivera R        15  2011
# 99    16         FLORIDA                           Rooney R         0  2011
# 100   18         FLORIDA                      RosLehtinen R        25  2011
# 101   12         FLORIDA                          Ross D. R         0  2011
# 102    2         FLORIDA                      Southerland R         0  2011
# 103    6         FLORIDA                          Stearns R         0  2011
# 104   20         FLORIDA                Wasserman Schultz D        80  2011
# 105    8         FLORIDA                          Webster R        10  2011
# 106   22         FLORIDA                          West A. R         5  2011
# 107   17         FLORIDA                        Wilson F. D        90  2011
# 108   10         FLORIDA                       Young C.W. R         0  2011
# 109   12         GEORGIA                           Barrow D        50  2011
# 110    2         GEORGIA                        Bishop S. D        55  2011
# 111   10         GEORGIA                            Broun R         5  2011
# 112   11         GEORGIA                          Gingrey R         0  2011
# 113    9         GEORGIA                        Graves T. R         5  2011
# 114    4         GEORGIA                       Johnson H. D        90  2011
# 115    1         GEORGIA                         Kingston R         5  2011
# 116    5         GEORGIA                       Lewis John D       100  2011
# 117    6         GEORGIA                         Price T. R         0  2011
# 118    8         GEORGIA                         Scott A. R         0  2011
# 119   13         GEORGIA                         Scott D. D        75  2011
# 120    3         GEORGIA                  Westmoreland L. R         0  2011
# 121    7         GEORGIA                          Woodall R         5  2011
# 122    1          HAWAII                         Hanabusa D        85  2011
# 123    2          HAWAII                           Hirono D        95  2011
# 124    1           IDAHO                         Labrador R        15  2011
# 125    2           IDAHO                          Simpson R        15  2011
# 126   13        ILLINOIS                          Biggert R        25  2011
# 127   12        ILLINOIS                         Costello D        80  2011
# 128    7        ILLINOIS                         Davis D. D        95  2011
# 129   10        ILLINOIS                             Dold R        25  2011
# 130    4        ILLINOIS                        Gutierrez D        85  2011
# 131   14        ILLINOIS                         Hultgren R        15  2011
# 132    2        ILLINOIS                       Jackson J. D       100  2011
# 133   15        ILLINOIS                  Johnson Timothy R        40  2011
# 134   11        ILLINOIS                        Kinzinger R        15  2011
# 135    3        ILLINOIS                         Lipinski D        65  2011
# 136   16        ILLINOIS                         Manzullo R        10  2011
# 137    5        ILLINOIS                          Quigley D        85  2011
# 138    6        ILLINOIS                           Roskam R        10  2011
# 139    1        ILLINOIS                             Rush D        85  2011
# 140    9        ILLINOIS                       Schakowsky D       100  2011
# 141   17        ILLINOIS                        Schilling R        30  2011
# 142   18        ILLINOIS                           Schock R        10  2011
# 143   19        ILLINOIS                          Shimkus R         5  2011
# 144    8        ILLINOIS                            Walsh R         5  2011
# 145    8         INDIANA                          Bucshon R         5  2011
# 146    5         INDIANA                           Burton R         0  2011
# 147    7         INDIANA                           Carson D        95  2011
# 148    2         INDIANA                         Donnelly D        55  2011
# 149    6         INDIANA                            Pence R         0  2011
# 150    4         INDIANA                           Rokita R         0  2011
# 151    3         INDIANA                         Stutzman R         0  2011
# 152    1         INDIANA                        Visclosky D        90  2011
# 153    9         INDIANA                         Young T. R         0  2011
# 154    3            IOWA                          Boswell D        75  2011
# 155    1            IOWA                           Braley D        80  2011
# 156    5            IOWA                          King S. R         0  2011
# 157    4            IOWA                           Latham R        10  2011
# 158    2            IOWA                         Loebsack D        85  2011
# 159    1          KANSAS                        Huelskamp R         0  2011
# 160    2          KANSAS                          Jenkins R         0  2011
# 161    4          KANSAS                           Pompeo R         0  2011
# 162    3          KANSAS                            Yoder R         0  2011
# 163    6        KENTUCKY                         Chandler D        60  2011
# 164    4        KENTUCKY                         Davis G. R         5  2011
# 165    2        KENTUCKY                          Guthrie R         5  2011
# 166    5        KENTUCKY                        Rogers H. R         5  2011
# 167    1        KENTUCKY                       Whitfi eld R         5  2011
# 168    3        KENTUCKY                          Yarmuth D        90  2011
# 169    5       LOUISIANA                     Alexander R. R         5  2011
# 170    7       LOUISIANA                         Boustany R         0  2011
# 171    6       LOUISIANA                          Cassidy R         0  2011
# 172    4       LOUISIANA                          Fleming R         0  2011
# 173    3       LOUISIANA                        Landry J. R         5  2011
# 174    2       LOUISIANA                         Richmond D        90  2011
# 175    1       LOUISIANA                          Scalise R         0  2011
# 176    2           MAINE                          Michaud D        95  2011
# 177    1           MAINE                          Pingree D        90  2011
# 178    6        MARYLAND                         Bartlett R        15  2011
# 179    7        MARYLAND                         Cummings D        95  2011
# 180    4        MARYLAND                          Edwards D       100  2011
# 181    1        MARYLAND                           Harris R        10  2011
# 182    5        MARYLAND                            Hoyer D        75  2011
# 183    2        MARYLAND                    Ruppersberger D        80  2011
# 184    3        MARYLAND                         Sarbanes D        95  2011
# 185    8        MARYLAND                       Van Hollen D        80  2011
# 186    8   MASSACHUSETTS                          Capuano D       100  2011
# 187    4   MASSACHUSETTS                         Frank B. D        95  2011
# 188   10   MASSACHUSETTS                          Keating D        85  2011
# 189    9   MASSACHUSETTS                            Lynch D        80  2011
# 190    7   MASSACHUSETTS                           Markey D       100  2011
# 191    3   MASSACHUSETTS                         McGovern D       100  2011
# 192    2   MASSACHUSETTS                             Neal D        85  2011
# 193    1   MASSACHUSETTS                            Olver D        85  2011
# 194    6   MASSACHUSETTS                          Tierney D        95  2011
# 195    5   MASSACHUSETTS                          Tsongas D        90  2011
# 196    3        MICHIGAN         Amash R    P   P         P        20  2011
# 197    1        MICHIGAN                         Benishek R         0  2011
# 198    4        MICHIGAN                             Camp R         5  2011
# 199   13        MICHIGAN                           Clarke D       100  2011
# 200   14        MICHIGAN                          Conyers D       100  2011
# 201   15        MICHIGAN                          Dingell D        85  2011
# 202    2        MICHIGAN                         Huizenga R         0  2011
# 203    5        MICHIGAN                           Kildee D        90  2011
# 204   12        MICHIGAN                         Levin S. D        80  2011
# 205   11        MICHIGAN                         McCotter R        15  2011
# 206   10        MICHIGAN                        Miller C. R        10  2011
# 207    9        MICHIGAN                           Peters D        75  2011
# 208    8        MICHIGAN                      Rogers Mike R         5  2011
# 209    6        MICHIGAN                            Upton R         5  2011
# 210    7        MICHIGAN                          Walberg R         5  2011
# 211    6       MINNESOTA                         Bachmann R         0  2011
# 212    8       MINNESOTA                         Cravaack R        10  2011
# 213    5       MINNESOTA                          Ellison D        95  2011
# 214    2       MINNESOTA                         Kline J. R         5  2011
# 215    4       MINNESOTA                         McCollum D        80  2011
# 216    3       MINNESOTA                          Paulsen R         0  2011
# 217    7       MINNESOTA                         Peterson D        50  2011
# 218    1       MINNESOTA                             Walz D        85  2011
# 219    3     MISSISSIPPI                           Harper R         5  2011
# 220    1     MISSISSIPPI                         Nunnelee R         0  2011
# 221    4     MISSISSIPPI                          Palazzo R         0  2011
# 222    2     MISSISSIPPI                      Thompson B. D        90  2011
# 223    2        MISSOURI                             Akin R         0  2011
# 224    3        MISSOURI                         Carnahan D        80  2011
# 225    1        MISSOURI                             Clay D        95  2011
# 226    5        MISSOURI                          Cleaver D        95  2011
# 227    8        MISSOURI                          Emerson R        25  2011
# 228    6        MISSOURI                        Graves S. R        20  2011
# 229    4        MISSOURI                         Hartzler R         5  2011
# 230    7        MISSOURI                             Long R         0  2011
# 231    9        MISSOURI                      Luetkemeyer R         0  2011
# 232   AL         MONTANA                          Rehberg R        25  2011
# 233    1        NEBRASKA                      Fortenberry R        15  2011
# 234    3        NEBRASKA                     Smith Adrian R         0  2011
# 235    2        NEBRASKA                            Terry R         5  2011
# 236    1          NEVADA                          Berkley D        80  2011
# 237    3          NEVADA                             Heck R        15  2011
# 238    2   NEW HAMPSHIRE                          Bass C. R        15  2011
# 239    1   NEW HAMPSHIRE                           Guinta R         0  2011
# 240    1      NEW JERSEY                          Andrews D        85  2011
# 241   11      NEW JERSEY                    Frelinghuysen R        15  2011
# 242    5      NEW JERSEY                          Garrett R         0  2011
# 243   12      NEW JERSEY                             Holt D       100  2011
# 244    7      NEW JERSEY                            Lance R        20  2011
# 245    2      NEW JERSEY                         LoBiondo R        35  2011
# 246    6      NEW JERSEY                          Pallone D       100  2011
# 247    8      NEW JERSEY                         Pascrell D        75  2011
# 248   10      NEW JERSEY                            Payne D        95  2011
# 249    9      NEW JERSEY                          Rothman D        75  2011
# 250    3      NEW JERSEY                           Runyan R        20  2011
# 251   13      NEW JERSEY                            Sires D        80  2011
# 252    4      NEW JERSEY                         Smith C. R        30  2011
# 253    1      NEW MEXICO                         Heinrich D        85  2011
# 254    3      NEW MEXICO                            Lujan D        90  2011
# 255    2      NEW MEXICO                           Pearce R         5  2011
# 256    5        NEW YORK                         Ackerman D        75  2011
# 257    1        NEW YORK                        Bishop T. D        85  2011
# 258   25        NEW YORK                          Buerkle R         0  2011
# 259   11        NEW YORK                           Clarke D       100  2011
# 260    7        NEW YORK                          Crowley D        80  2011
# 261   17        NEW YORK                            Engel D        90  2011
# 262   20        NEW YORK                        Gibson C. R        30  2011
# 263   13        NEW YORK                            Grimm R        25  2011
# 264   24        NEW YORK                            Hanna R        25  2011
# 265   19        NEW YORK                         Hayworth R        10  2011
# 266   27        NEW YORK                          Higgins D        80  2011
# 267   22        NEW YORK                          Hinchey D        80  2011
# 268   26        NEW YORK   Hochul D I I I I I I I I I I I I        30  2011
# 269    2        NEW YORK                           Israel D        85  2011
# 270    3        NEW YORK                          King P. R        25  2011
# 271   18        NEW YORK                            Lowey D        80  2011
# 272   14        NEW YORK                          Maloney D        85  2011
# 273    4        NEW YORK                      McCarthy C. D        65  2011
# 274    6        NEW YORK                         Meeks G. D        75  2011
# 275    8        NEW YORK                           Nadler D       100  2011
# 276   23        NEW YORK                            Owens D        70  2011
# 277   15        NEW YORK                           Rangel D        90  2011
# 278   29        NEW YORK                          Reed T. R         5  2011
# 279   16        NEW YORK                          Serrano D       100  2011
# 280   28        NEW YORK                        Slaughter D        95  2011
# 281   21        NEW YORK                            Tonko D       100  2011
# 282   10        NEW YORK                            Towns D       100  2011
# 283   12        NEW YORK                        Velazquez D        95  2011
# 284    1  NORTH CAROLINA                     Butterfi eld D        85  2011
# 285    6  NORTH CAROLINA                            Coble R        10  2011
# 286    2  NORTH CAROLINA                          Ellmers R         5  2011
# 287    5  NORTH CAROLINA                             Foxx R         5  2011
# 288    3  NORTH CAROLINA                            Jones R        40  2011
# 289    8  NORTH CAROLINA                          Kissell D        60  2011
# 290   10  NORTH CAROLINA                          McHenry R         5  2011
# 291    7  NORTH CAROLINA                         McIntyre D        40  2011
# 292   13  NORTH CAROLINA                        Miller B. D        85  2011
# 293    9  NORTH CAROLINA                           Myrick R         5  2011
# 294    4  NORTH CAROLINA                         Price D. D        85  2011
# 295   11  NORTH CAROLINA                           Shuler D        60  2011
# 296   12  NORTH CAROLINA                             Watt D       100  2011
# 297   AL    NORTH DAKOTA                             Berg R         0  2011
# 298    7            OHIO                          Austria R         5  2011
# 299    1            OHIO                           Chabot R         0  2011
# 300   11            OHIO                            Fudge D        95  2011
# 301   18            OHIO                         Gibbs B. R         0  2011
# 302    6            OHIO                       Johnson B. R         5  2011
# 303    4            OHIO                           Jordan R         0  2011
# 304    9            OHIO                           Kaptur D        90  2011
# 305   10            OHIO                         Kucinich D       100  2011
# 306   14            OHIO                       LaTourette R        30  2011
# 307    5            OHIO                            Latta R         0  2011
# 308   16            OHIO                          Renacci R         0  2011
# 309   17            OHIO                          Ryan T. D        90  2011
# 310    2            OHIO                          Schmidt R         5  2011
# 311   15            OHIO                          Stivers R        10  2011
# 312   13            OHIO                           Sutton D        90  2011
# 313   12            OHIO                           Tiberi R        10  2011
# 314    3            OHIO                           Turner R        10  2011
# 315    2        OKLAHOMA                            Boren D        30  2011
# 316    4        OKLAHOMA                             Cole R         0  2011
# 317    5        OKLAHOMA                         Lankford R         0  2011
# 318    3        OKLAHOMA                            Lucas R         0  2011
# 319    1        OKLAHOMA                         Sullivan R         0  2011
# 320    3          OREGON                       Blumenauer D        85  2011
# 321    4          OREGON                          DeFazio D        90  2011
# 322    5          OREGON                         Schrader D        70  2011
# 323    2          OREGON                           Walden R        10  2011
# 324    1          OREGON       Wu D                 I I I I        75  2011
# 325    4    PENNSYLVANIA                          Altmire D        65  2011
# 326   11    PENNSYLVANIA                         Barletta R        15  2011
# 327    1    PENNSYLVANIA                         Brady R. D        90  2011
# 328   12    PENNSYLVANIA                            Critz D        80  2011
# 329   15    PENNSYLVANIA                             Dent R        10  2011
# 330   14    PENNSYLVANIA                            Doyle D        95  2011
# 331    2    PENNSYLVANIA                           Fattah D        90  2011
# 332    8    PENNSYLVANIA                      Fitzpatrick R        20  2011
# 333    6    PENNSYLVANIA                          Gerlach R        15  2011
# 334   17    PENNSYLVANIA                           Holden D        70  2011
# 335    3    PENNSYLVANIA                            Kelly R        10  2011
# 336   10    PENNSYLVANIA                           Marino R         5  2011
# 337    7    PENNSYLVANIA                           Meehan R        15  2011
# 338   18    PENNSYLVANIA                        Murphy T. R        15  2011
# 339   16    PENNSYLVANIA                            Pitts R         0  2011
# 340   19    PENNSYLVANIA                           Platts R         5  2011
# 341   13    PENNSYLVANIA                         Schwartz D        75  2011
# 342    9    PENNSYLVANIA                          Shuster R        10  2011
# 343    5    PENNSYLVANIA                      Thompson G. R         5  2011
# 344    1    RHODE ISLAND                        Cicilline D       100  2011
# 345    2    RHODE ISLAND                         Langevin D        80  2011
# 346    6  SOUTH CAROLINA                          Clyburn D        90  2011
# 347    3  SOUTH CAROLINA                           Duncan R         5  2011
# 348    4  SOUTH CAROLINA                            Gowdy R         5  2011
# 349    5  SOUTH CAROLINA                         Mulvaney R         5  2011
# 350    1  SOUTH CAROLINA                         Scott T. R         0  2011
# 351    2  SOUTH CAROLINA                        Wilson J. R         5  2011
# 352   AL    SOUTH DAKOTA                             Noem R         0  2011
# 353    6       TENNESSEE                         Black D. R         5  2011
# 354    7       TENNESSEE                     Blackburn M. R         0  2011
# 355    9       TENNESSEE                            Cohen D        95  2011
# 356    5       TENNESSEE                           Cooper D        60  2011
# 357    4       TENNESSEE                       DesJarlais R         0  2011
# 358    2       TENNESSEE                           Duncan R        20  2011
# 359    8       TENNESSEE                          Fincher R         0  2011
# 360    3       TENNESSEE                      Fleischmann R         0  2011
# 361    1       TENNESSEE                              Roe R        10  2011
# 362    6           TEXAS                           Barton R         5  2011
# 363    8           TEXAS                         Brady K. R         0  2011
# 364   26           TEXAS                          Burgess R         5  2011
# 365   23           TEXAS                          Canseco R         0  2011
# 366   31           TEXAS                           Carter R         0  2011
# 367   11           TEXAS                          Conaway R         0  2011
# 368   28           TEXAS                          Cuellar D        50  2011
# 369    7           TEXAS                        Culberson R         5  2011
# 370   25           TEXAS                          Doggett D        90  2011
# 371   27           TEXAS                       Farenthold R        10  2011
# 372   17           TEXAS                           Flores R         0  2011
# 373    1           TEXAS                          Gohmert R         5  2011
# 374   20           TEXAS                         Gonzalez D        75  2011
# 375   12           TEXAS                            Granger         0  2011
# 376    9           TEXAS                         Green A. D        85  2011
# 377   29           TEXAS                         Green G. D        85  2011
# 378    4           TEXAS                          Hall R. R         0  2011
# 379    5           TEXAS                       Hensarling R         0  2011
# 380   15           TEXAS                         Hinojosa D        70  2011
# 381   18           TEXAS                      Jackson Lee D        90  2011
# 382    3           TEXAS                       Johnson S. R         0  2011
# 383   30           TEXAS                       Johnson E. D        95  2011
# 384   24           TEXAS                         Marchant R        10  2011
# 385   10           TEXAS                           McCaul R         0  2011
# 386   19           TEXAS                         Neugebauer         0  2011
# 387   22           TEXAS                            Olson R         0  2011
# 388   14           TEXAS                         Paul Ron R        25  2011
# 389    2           TEXAS                              Poe R         0  2011
# 390   16           TEXAS                            Reyes D        70  2011
# 391   32           TEXAS                      Sessions P. R         0  2011
# 392   21           TEXAS                        Smith Lamar         0  2011
# 393   13           TEXAS                       Thornberry R         0  2011
# 394    1            UTAH                        Bishop R. R        20  2011
# 395    3            UTAH                         Chaffetz R        10  2011
# 396    2            UTAH                         Matheson D        50  2011
# 397   AL         VERMONT                            Welch D       100  2011
# 398    7        VIRGINIA                           Cantor R         0  2011
# 399   11        VIRGINIA                         Connolly D        80  2011
# 400    4        VIRGINIA                           Forbes R         5  2011
# 401    6        VIRGINIA                        Goodlatte R         0  2011
# 402    9        VIRGINIA                        Griffi th R        20  2011
# 403    5        VIRGINIA                             Hurt R         5  2011
# 404    8        VIRGINIA                      Moran James D        90  2011
# 405    2        VIRGINIA                           Rigell R        10  2011
# 406    3        VIRGINIA                         Scott R. D        80  2011
# 407    1        VIRGINIA                          Wittman R         5  2011
# 408   10        VIRGINIA                             Wolf R         5  2011
# 409    6      WASHINGTON                            Dicks D        80  2011
# 410    4      WASHINGTON                      Hastings D. R         0  2011
# 411    3      WASHINGTON                  Herrera Beutler R        10  2011
# 412    1      WASHINGTON                           Inslee D        80  2011
# 413    2      WASHINGTON                        Larsen R. D        85  2011
# 414    7      WASHINGTON                        McDermott D        95  2011
# 415    5      WASHINGTON                 McMorris Rodgers R         0  2011
# 416    8      WASHINGTON                         Reichert R        25  2011
# 417    9      WASHINGTON                       Smith Adam D        75  2011
# 418    2   WEST VIRGINIA                           Capito R        15  2011
# 419    1   WEST VIRGINIA                         McKinley R        25  2011
# 420    3   WEST VIRGINIA                           Rahall D        65  2011
# 421    2       WISCONSIN                          Baldwin D        95  2011
# 422    7       WISCONSIN                            Duffy R         5  2011
# 423    3       WISCONSIN                             Kind D        75  2011
# 424    4       WISCONSIN                            Moore D        95  2011
# 425    6       WISCONSIN                            Petri R        15  2011
# 426    8       WISCONSIN                           Ribble R         0  2011
# 427    1       WISCONSIN                          Ryan P. R        15  2011
# 428    5       WISCONSIN                    Sensenbrenner R         5  2011
# 429   AL         WYOMING                           Lummis R         0  2011
# 430   on         WYOMING  the th would receive a score of .         0  2011
